# %% [markdown]
# # 환경 설정

# %%
# !pip install tensorflow-gpu==1.15

# %% [markdown]
# # 구글드라이브 연결

# %%
from google.colab import drive
import os

drive.mount('/content/drive/')
os.chdir('drive/My Drive')
# !ls

# %%
os.chdir('coLab/korbert')

# %% [markdown]
# # bert 실행

# %%
# !python run_squad.py
